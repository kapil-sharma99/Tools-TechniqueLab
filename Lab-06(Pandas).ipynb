# %%
import pandas as pd

# %%
#Creating dataframe using pd.DataFrame
mydataset = {
    'cars': ["BMW", "Volvo", "Ford"],
    'passings': [3,7,3]
}
myvar = pd.DataFrame(mydataset)
print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         3

# %%
print(pd.__version__)
# Out:
# 1.2.4

# %%
#Creating series using pd.Series
a = [1,7,2]
myvar = pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
print(myvar[1])
# Out:
# 7

# %%
#Creating Series with customized index.
index = ["x", "y", "z"]
a = [1,7,2]
myvar = pd.Series(a, index=index)
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
#Creating series using dictionary
calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories)
print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
#Creating dataframe using dictionary.
data = {
    "calories": [420, 380, 390],
    "duration": [50, 40, 45]
}
myvar = pd.DataFrame(data)
print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
print(myvar.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
print(myvar.loc[[0,1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %%
print("Day1: ")
print(myvar.loc[0])
print("Day2: ")
print(myvar.loc[1])
print("Day3: ")
print(myvar.loc[2])
# Out:
# Day1:
# calories    420
# duration     50
# Name: 0, dtype: int64
# Day2:
# calories    380
# duration     40
# Name: 1, dtype: int64
# Day3:
# calories    390
# duration     45
# Name: 2, dtype: int64

# %%
df = pd.read_csv("Salaries.csv")
df
# Out:
#          rank discipline   phd  service     sex    salary
# 0        Prof          B  56.0       49    Male  186960.0
# 1        Prof          A  12.0        6    Male   93000.0
# 2        Prof          A  23.0       20    Male  110515.0
# 3        Prof          A  40.0       31    Male  131205.0
# 4        Prof          B  20.0       18    Male  104800.0
# ..        ...        ...   ...      ...     ...       ...
# 73       Prof          B  18.0       10  Female  105450.0
# 74  AssocProf          B  19.0        6  Female  104542.0
# 75       Prof          B  17.0       17  Female  124312.0
# 76       Prof          A  28.0       14  Female  109954.0
# 77       Prof          A  23.0       15  Female  109646.0
#
# [78 rows x 6 columns]

# %%
df.head()
# Out:
#    rank discipline   phd  service   sex    salary
# 0  Prof          B  56.0       49  Male  186960.0
# 1  Prof          A  12.0        6  Male   93000.0
# 2  Prof          A  23.0       20  Male  110515.0
# 3  Prof          A  40.0       31  Male  131205.0
# 4  Prof          B  20.0       18  Male  104800.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         76 non-null     float64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      76 non-null     float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 3.8+ KB

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           2
# service       0
# sex           0
# salary        2
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#          rank discipline   phd  service     sex    salary
# 0        Prof          B  56.0       49    Male  186960.0
# 1        Prof          A  12.0        6    Male   93000.0
# 2        Prof          A  23.0       20    Male  110515.0
# 3        Prof          A  40.0       31    Male  131205.0
# 4        Prof          B  20.0       18    Male  104800.0
# ..        ...        ...   ...      ...     ...       ...
# 73       Prof          B  18.0       10  Female  105450.0
# 74  AssocProf          B  19.0        6  Female  104542.0
# 75       Prof          B  17.0       17  Female  124312.0
# 76       Prof          A  28.0       14  Female  109954.0
# 77       Prof          A  23.0       15  Female  109646.0
#
# [74 rows x 6 columns]

# %%
df.fillna("Error", inplace=True)
df.head(50)
# Out:
#          rank discipline   phd  service     sex    salary  salary2
# 0        Prof          B  56.0       49    Male  100000.0     True
# 1        Prof          A  12.0        6    Male   93000.0     True
# 2        Prof          A  23.0       20    Male  100000.0     True
# 3        Prof          A  40.0       31    Male  100000.0     True
# 4        Prof          B  20.0       18    Male  100000.0     True
# 5        Prof          A  20.0       20    Male  100000.0     True
# 6   AssocProf          A  20.0       17    Male   81285.0     True
# 8        Prof          A  29.0       19    Male   94350.0     True
# 9        Prof          A  51.0       51    Male   57800.0    False
# 10       Prof          B  39.0       33    Male  100000.0     True
# 11       Prof          B  23.0       23    Male  100000.0     True
# 12   AsstProf          B   1.0        0    Male   88000.0     True
# 14       Prof          B  25.0       19    Male  100000.0     True
# ...

# %%
df["salary"].fillna(45000, inplace=True)
df
# Out:
#          rank discipline   phd  service     sex    salary
# 0        Prof          B  56.0       49    Male  186960.0
# 1        Prof          A  12.0        6    Male   93000.0
# 2        Prof          A  23.0       20    Male  110515.0
# 3        Prof          A  40.0       31    Male  131205.0
# 4        Prof          B  20.0       18    Male  104800.0
# ..        ...        ...   ...      ...     ...       ...
# 73       Prof          B  18.0       10  Female  105450.0
# 74  AssocProf          B  19.0        6  Female  104542.0
# 75       Prof          B  17.0       17  Female  124312.0
# 76       Prof          A  28.0       14  Female  109954.0
# 77       Prof          A  23.0       15  Female  109646.0
#
# [74 rows x 6 columns]

# %%
for x in df.index:
    if df.loc[x, "salary"] > 100000:
        df.loc[x, "salary"] = 100000
df
# Out:
#          rank discipline   phd  service     sex    salary
# 0        Prof          B  56.0       49    Male  100000.0
# 1        Prof          A  12.0        6    Male   93000.0
# 2        Prof          A  23.0       20    Male  100000.0
# 3        Prof          A  40.0       31    Male  100000.0
# 4        Prof          B  20.0       18    Male  100000.0
# ..        ...        ...   ...      ...     ...       ...
# 73       Prof          B  18.0       10  Female  100000.0
# 74  AssocProf          B  19.0        6  Female  100000.0
# 75       Prof          B  17.0       17  Female  100000.0
# 76       Prof          A  28.0       14  Female  100000.0
# 77       Prof          A  23.0       15  Female  100000.0
#
# [74 rows x 6 columns]

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 73    False
# 74    False
# 75     True
# 76    False
# 77    False
# Length: 74, dtype: bool

# %%
df.duplicated("salary").sum()
# Out:
# 47

# %%
df.shape
# Out:
# (74, 6)

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df['salary']
# Out:
# 0     100000.0
# 1      93000.0
# 2     100000.0
# 3     100000.0
# 4     100000.0
#         ...
# 73    100000.0
# 74    100000.0
# 75    100000.0
# 76    100000.0
# 77    100000.0
# Name: salary, Length: 74, dtype: float64

# %%
df.head(3)
# Out:
#    rank discipline   phd  service   sex    salary
# 0  Prof          B  56.0       49  Male  100000.0
# 1  Prof          A  12.0        6  Male   93000.0
# 2  Prof          A  23.0       20  Male  100000.0

# %%
df.tail(3)
# Out:
#     rank discipline   phd  service     sex    salary
# 75  Prof          B  17.0       17  Female  100000.0
# 76  Prof          A  28.0       14  Female  100000.0
# 77  Prof          A  23.0       15  Female  100000.0

# %%
df.sample(10)
# Out:
#         rank discipline   phd  service     sex    salary
# 66  AsstProf          A   7.0        6  Female   63100.0
# 35      Prof          B  28.0       23    Male  100000.0
# 36      Prof          B  45.0       45    Male  100000.0
# 22  AsstProf          A   4.0        2    Male   73000.0
# 29      Prof          B  21.0       20    Male  100000.0
# 25      Prof          B  35.0       31    Male   99418.0
# 23  AsstProf          A   2.0        0    Male   85000.0
# 37      Prof          A  20.0        8    Male  100000.0
# 8       Prof          A  29.0       19    Male   94350.0
# 52      Prof          A  12.0        0  Female  100000.0

# %%
df[['salary', 'phd', 'sex']]
# Out:
#       salary   phd     sex
# 0   100000.0  56.0    Male
# 1    93000.0  12.0    Male
# 2   100000.0  23.0    Male
# 3   100000.0  40.0    Male
# 4   100000.0  20.0    Male
# ..       ...   ...     ...
# 73  100000.0  18.0  Female
# 74  100000.0  19.0  Female
# 75  100000.0  17.0  Female
# 76  100000.0  28.0  Female
# 77  100000.0  23.0  Female
#
# [74 rows x 3 columns]

# %%
df['salary'].mean()
# Out:
# 92061.82432432432

# %%
df['rank'].unique()
# Out:
# array(['Prof', 'AssocProf', 'AsstProf'], dtype=object)

# %%
df['rank'].value_counts()
# Out:
# Prof         44
# AsstProf     18
# AssocProf    12
# Name: rank, dtype: int64

# %%
salary2 = df['salary'] > 80000
df['salary2'] = salary2
df
# Out:
#          rank discipline   phd  service     sex    salary  salary2
# 0        Prof          B  56.0       49    Male  100000.0     True
# 1        Prof          A  12.0        6    Male   93000.0     True
# 2        Prof          A  23.0       20    Male  100000.0     True
# 3        Prof          A  40.0       31    Male  100000.0     True
# 4        Prof          B  20.0       18    Male  100000.0     True
# ..        ...        ...   ...      ...     ...       ...      ...
# 73       Prof          B  18.0       10  Female  100000.0     True
# 74  AssocProf          B  19.0        6  Female  100000.0     True
# 75       Prof          B  17.0       17  Female  100000.0     True
# 76       Prof          A  28.0       14  Female  100000.0     True
# 77       Prof          A  23.0       15  Female  100000.0     True
#
# [74 rows x 7 columns]

# %%
x = (df['salary']<80000) & (df['sex'] == "Male")
df[x]
# Out:
#         rank discipline   phd  service   sex   salary  salary2
# 9       Prof          A  51.0       51  Male  57800.0    False
# 16  AsstProf          B   8.0        3  Male  75044.0    False
# 22  AsstProf          A   4.0        2  Male  73000.0    False

# %%
df.iloc[5:10, 0:3]
# Out:
#          rank discipline   phd
# 5        Prof          A  20.0
# 6   AssocProf          A  20.0
# 8        Prof          A  29.0
# 9        Prof          A  51.0
# 10       Prof          B  39.0

# %%
#Using titanic.csv file
df2 = pd.read_csv("training_titanic.csv")
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df2.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df2.shape
# Out:
# (891, 12)

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.drop_duplicates(inplace=True)
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2['Cabin'].value_counts()
# Out:
# G6             4
# B96 B98        4
# C23 C25 C27    4
# F2             3
# C22 C26        3
#               ..
# B37            1
# C103           1
# C118           1
# E63            1
# D21            1
# Name: Cabin, Length: 147, dtype: int64

# %%
df2.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df2.iloc[:,:]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.iloc[:30, 0:5]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
df2['Age'].fillna(df2['Age'].mean(), inplace=True)
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df2.dropna(inplace=True)
df2.shape
# Out:
# (202, 12)

# %%
print(df2.head(20).to_string())
# Out:
#      PassengerId  Survived  Pclass                                                 Name     Sex        Age  SibSp  Parch       Ticket      Fare        Cabin Embarked
# 1              2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.000000      1      0     PC 17599   71.2833          C85        C
# 3              4         1       1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000      1      0       113803   53.1000         C123        S
# 6              7         0       1                              McCarthy, Mr. Timothy J    male  54.000000      0      0        17463   51.8625          E46        S
# 10            11         1       3                      Sandstrom, Miss. Marguerite Rut  female   4.000000      1      1      PP 9549   16.7000           G6        S
# ...

# %%
df2.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 453          454         1       1
# 473          474         1       2
# 486          487         1       1
# 839          840         1       1
# 516          517         1       2
# 515          516         0       1
# 627          628         1       1
# 572          573         1       1
# 1              2         1       1
# 97            98         1       1
#
#                                                   Name     Sex        Age  \
# 453                           Goldenberg, Mr. Samuel L    male  49.000000
# 473       Jerwan, Mrs. Amin S (Marie Marthe Thuillard)  female  23.000000
# 486    Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)  female  35.000000
# 839                               Marechal, Mr. Pierre    male  29.699118
# 516                       Lemore, Mrs. (Amelia Milley)  female  34.000000
# 515                       Walker, Mr. William Anderson    male  47.000000
# ...

# %%
df2.tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 849          850         1       1
# 853          854         1       1
# 857          858         1       1
# 862          863         1       1
# 867          868         0       1
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex        Age  \
# 849       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female  29.699118
# 853                          Lines, Miss. Mary Conover  female  16.000000
# 857                             Daly, Mr. Peter Denis     male  51.000000
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.000000
# 867               Roebling, Mr. Washington Augustus II    male  31.000000
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.000000
# ...

# %%
df2.iloc[10:20, :]
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 54            55         0       1   Ostby, Mr. Engelhart Cornelius    male
# 55            56         1       1                Woolner, Mr. Hugh    male
# 62            63         0       1      Harris, Mr. Henry Birkhardt    male
# 66            67         1       2     Nye, Mrs. (Elizabeth Ramell)  female
# 75            76         0       3          Moen, Mr. Sigurd Hansen    male
# 88            89         1       1       Fortune, Miss. Mabel Helen  female
# 92            93         0       1      Chaffee, Mr. Herbert Fuller    male
# 96            97         0       1        Goldschmidt, Mr. George B    male
# 97            98         1       1  Greenfield, Mr. William Bertram    male
# 102          103         0       1        White, Mr. Richard Frasar    male
#
#            Age  SibSp  Parch       Ticket      Fare        Cabin Embarked
# ...

# %%
df2.isnull().mean()
# Out:
# PassengerId    0.0
# Survived       0.0
# Pclass         0.0
# Name           0.0
# Sex            0.0
# Age            0.0
# SibSp          0.0
# Parch          0.0
# Ticket         0.0
# Fare           0.0
# Cabin          0.0
# Embarked       0.0
# dtype: float64
